# %%
from ucimlrepo import fetch_ucirepo 
from sklearn.ensemble import VotingRegressor
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression,ElasticNet
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score,accuracy_score,log_loss,r2_score
from sklearn.model_selection import train_test_split,StratifiedKFold , GridSearchCV
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder

from sklearn.compose import make_column_transformer ,make_column_selector
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')

# %%
concrete_compressive_strength = fetch_ucirepo(id=165)

# %%
# data (as pandas dataframes) 
X = concrete_compressive_strength.data.features 
y = concrete_compressive_strength.data.targets

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=24,test_size=0.3)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr.predict(X_test)

# %%
print(r2_score(y_test,y_pred_lr))
# Out:
# 0.5771752777048791

# %%
el = ElasticNet(random_state=24)

# %%
el.fit(X_train,y_train)
# Out:
# ElasticNet(random_state=24)

# %%
y_pred_el = el.predict(X_test)

# %%
print(r2_score(y_test,y_pred_el))
# Out:
# 0.5766806310401154

# %%
dtr = DecisionTreeRegressor(random_state=24,max_depth=3)

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=24)

# %%
y_pred_dtr = dtr.predict(X_test)

# %%
print(r2_score(y_test,y_pred_dtr))
# Out:
# 0.5733507274413595

# %%
voting = VotingRegressor([('LR',lr),('EL',el),('DTR',dtr)])

# %%
voting.fit(X_train,y_train)
# Out:
# VotingRegressor(estimators=[('LR', LinearRegression()),
#                             ('EL', ElasticNet(random_state=24)),
#                             ('DTR',
#                              DecisionTreeRegressor(max_depth=3,
#                                                    random_state=24))])

# %%
y_pred_voting = voting.predict(X_test)

# %%
print(r2_score(y_test,y_pred_voting))
# Out:
# 0.6980882262572616

# %%
# OR

# %%
dtr1 = DecisionTreeRegressor(random_state=24,max_depth=None)

# %%
dtr2 = DecisionTreeRegressor(random_state=24,max_depth=None)

# %%
dtr3 = DecisionTreeRegressor(random_state=24,max_depth=None)

# %%
voting =VotingRegressor ([('M1',dtr1),('M2',dtr2),('M3',dtr3)] , 
          weights=[0.7,0.15,0.15])

# %%
voting.fit(X_train,y_train)
# Out:
# VotingRegressor(estimators=[('M1', DecisionTreeRegressor(random_state=24)),
#                             ('M2', DecisionTreeRegressor(random_state=24)),
#                             ('M3', DecisionTreeRegressor(random_state=24))],
#                 weights=[0.7, 0.15, 0.15])

# %%
y_pred = voting.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.83089474226832
